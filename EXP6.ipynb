# %%
#Experiment 6
#Name : Viraj Deshmukh
#PRN: 25070123123
#Title- Study of conditional statements in python

# %%
#1a. Check whether a number is positive, negative, or zero
number = int(input("Enter an integer: "))

if number > 0:
    print("Positive number")
elif number == 0:
  print("Negative number")
else:
  print("zero")
# Out:
# Enter an integer: 9
# Positive number

# %%
#2. Check whether a number is even or odd
number = int(input("Enter an integer: "))

if number % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter an integer: 9
# Odd number

# %%
#3. Find the largest of three numbers
num1 = int(input("Enter first integer: "))
num2 = int(input("Enter second integer: "))
num3 = int(input("Enter third integer: "))

if (num1 >= num2) and (num1 >= num3):
   largest = num1
elif (num2 >= num1) and (num2 >= num3):
   largest = num2
else:
   largest = num3

print("The largest number is", largest)
# Out:
# Enter first integer: 58487
# Enter second integer: 74848
# Enter third integer: 3807
# The largest number is 74848

# %%
#4. Get input from user for a subject and
#Calculate grade using if-else-elif
subject = input("Enter the subject name: ")
score = float(input(f"Enter the score for {subject}: "))

if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else:
    grade = 'F'

print(f"For {subject}, with a score of {score}, the grade is: {grade}")
# Out:
# Enter the subject name: english
# Enter the score for english: 78
# For english, with a score of 78.0, the grade is: C

# %%
#5. Check if a year is a leap year
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("is a leap year.")
else:
    print("is not a leap year.")
# Out:
# Enter a year: 1900
# is not a leap year.

# %%
#6. Increment a day by one day

# %%
#8. Check whether a character is a vowel or a consonant
char = input("Enter a character: ").lower()

if len(char) == 1 and char.isalpha():
    if char in ('a', 'e', 'i', 'o', 'u'):
        print(f"{char} is a vowel.")
    else:
        print(f"{char} is a consonant.")
else:
    print("Please enter a single alphabetic character.")
